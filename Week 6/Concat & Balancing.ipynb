# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')
train
# Out:
#         review_id                                             review  rating
# 0               0  Ga disappointed neat products .. Meletot Hilsn...       1
# 1               1    Rdtanya replace broken glass, broken chargernya       1
# 2               2  Nyesel bngt dsni shopping antecedent photo mes...       1
# 3               3      Sent a light blue suit goods ga want a refund       1
# 4               4  Pendants came with dents and scratches on its ...       1
# ...           ...                                                ...     ...
# 146806     146806  Excellent product quality delivery speed is ve...       5
# 146807     146807                                         thanks gan       5
# 146808     146808   Awesome awesome quality merchandise value CP ...       5
# 146809     146809  Nice Packing boxes made effective price .........       5
# 146810     146810   Excellent product quality excellent product p...       5
#
# [146811 rows x 3 columns]

# %%
train.rating.value_counts()
# Out:
# 4    41865
# 5    41515
# 3    35941
# 1    14785
# 2    12705
# Name: rating, dtype: int64

# %%
train_lama = pd.read_csv('test lama.csv')
sub_lama = pd.read_csv('Submission Lama.csv')
train_lama['rating'] = sub_lama['rating']
train_lama
# Out:
#        review_id                                             review  rating
# 0              0                                      slow delivery       1
# 1              1               Dateng goods do not conform pesanan😔       1
# 2              2                             PSN k its 20 other DTG       1
# 3              3  I am expected that it have a frame and painted...       1
# 4              4                   The product quality is not good.       1
# ...          ...                                                ...     ...
# 62913      62913  Has shipped It was the model that fits the cut...       5
# 62914      62914       Awesome awesome speed of the ship's value CP       5
# 62915      62915  but already in lebihin one of its usual size w...       5
# 62916      62916                  The product quality is excellent.       5
# 62917      62917  Excellent product quality, original product, t...       5
#
# [62918 rows x 3 columns]

# %%
baru = pd.concat([
    train,
    train_lama[(train_lama['rating'] == 1) | (train_lama['rating'] == 2)],
    train_lama[train_lama['rating'] == 5].sample(n = 41865 - 41515),
    train_lama[train_lama['rating'] == 3].sample(n = 41865 - 35941)
])
baru.shape
# Out:
# (164866, 3)

# %%
baru['review_id'] = list(range(164866))
baru
# Out:
#        review_id                                             review  rating
# 0              0  Ga disappointed neat products .. Meletot Hilsn...       1
# 1              1    Rdtanya replace broken glass, broken chargernya       1
# 2              2  Nyesel bngt dsni shopping antecedent photo mes...       1
# 3              3      Sent a light blue suit goods ga want a refund       1
# 4              4  Pendants came with dents and scratches on its ...       1
# ...          ...                                                ...     ...
# 12519     164861  Okay great, make more ka thicker version. Good...       3
# 21359     164862  Product quality good price good product delive...       3
# 16583     164863  Mayan's just outgrown tp sdikit okay lah ........       3
# 24110     164864        suitable hopefully I'll be ksih bitang full       3
# 23395     164865  Now Black has a red color. 👎👎👎👎👎👎👎👎👎👎👎👎👎👎👎👎👎👎👎...       3
#
# [164866 rows x 3 columns]

# %%
import seaborn as sns
sns.countplot(baru.rating)

# %%
baru.to_csv('train baru.csv')
